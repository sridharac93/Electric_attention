# %% [markdown]
# ### Importing Required Libraries

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Reading the Dataset

# %%
df = pd.read_csv("detect_dataset.csv")

# %%
df.head()
# Out:
#    Output (S)          Ia        Ib          Ic        Va        Vb        Vc  \
# 0           0 -170.472196  9.219613  161.252583  0.054490 -0.659921  0.605431
# 1           0 -122.235754  6.168667  116.067087  0.102000 -0.628612  0.526202
# 2           0  -90.161474  3.813632   86.347841  0.141026 -0.605277  0.464251
# 3           0  -79.904916  2.398803   77.506112  0.156272 -0.602235  0.445963
# 4           0  -63.885255  0.590667   63.294587  0.180451 -0.591501  0.411050
#
#    Unnamed: 7  Unnamed: 8
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df['Output (S)'].value_counts()
# Out:
# 0    6505
# 1    5496
# Name: Output (S), dtype: int64

# %% [markdown]
# ### Removing the unnecessary columns

# %%
df.drop(['Unnamed: 7','Unnamed: 8'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#    Output (S)          Ia        Ib          Ic        Va        Vb        Vc
# 0           0 -170.472196  9.219613  161.252583  0.054490 -0.659921  0.605431
# 1           0 -122.235754  6.168667  116.067087  0.102000 -0.628612  0.526202
# 2           0  -90.161474  3.813632   86.347841  0.141026 -0.605277  0.464251
# 3           0  -79.904916  2.398803   77.506112  0.156272 -0.602235  0.445963
# 4           0  -63.885255  0.590667   63.294587  0.180451 -0.591501  0.411050

# %%
df['Output (S)'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12001 entries, 0 to 12000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Output (S)  12001 non-null  int64
#  1   Ia          12001 non-null  float64
#  2   Ib          12001 non-null  float64
#  3   Ic          12001 non-null  float64
#  4   Va          12001 non-null  float64
#  5   Vb          12001 non-null  float64
#  6   Vc          12001 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 656.4 KB

# %%
sns.pairplot(df.corr())
plt.show()

# %%
sns.countplot(data = df, x = 'Output (S)')
plt.show()

# %%
sns.lineplot(data = df)
plt.show()

# %%
sns.scatterplot(data = df,x = 'Ia',y = 'Va')
plt.show()

# %%
sns.scatterplot(data = df,x = 'Va',y = 'Vb')
plt.show()

# %%
sns.distplot(df['Va'],bins = 20)
plt.show()
# Out:
# C:\Users\91789\.conda\envs\tf_gpu\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.heatmap(df.corr(),annot=True,cmap = 'coolwarm')
plt.show()

# %%
sns.lineplot(data = df,x = 'Va',y = 'Output (S)')
plt.show()

# %%
df.corr()
# Out:
#             Output (S)        Ia        Ib        Ic        Va        Vb  \
# Output (S)    1.000000  0.039408 -0.134028  0.120044 -0.035377  0.012206
# Ia            0.039408  1.000000 -0.375477 -0.275694  0.032598 -0.158207
# Ib           -0.134028 -0.375477  1.000000 -0.530187 -0.027052  0.032248
# Ic            0.120044 -0.275694 -0.530187  1.000000 -0.001813 -0.096194
# Va           -0.035377  0.032598 -0.027052 -0.001813  1.000000 -0.507928
# Vb            0.012206 -0.158207  0.032248 -0.096194 -0.507928  1.000000
# Vc            0.022570  0.129686 -0.006205  0.100298 -0.471163 -0.520478
#
#                   Vc
# Output (S)  0.022570
# Ia          0.129686
# Ib         -0.006205
# Ic          0.100298
# Va         -0.471163
# Vb         -0.520478
# Vc          1.000000

# %% [markdown]
# ### Reading Inputs & Outputs

# %%
x = df[['Ia','Ia','Ic','Va','Vb','Vc']]

# %%
y = df['Output (S)']

# %% [markdown]
# ### Splitting the data into training and testing sets

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %% [markdown]
# ### Model Building

# %%
model = tf.keras.Sequential()

# %%
model.add(tf.keras.layers.Dense(128,activation = 'relu', input_shape = (6,)))
model.add(tf.keras.layers.Dense(256,activation = 'relu'))
model.add(tf.keras.layers.Dense(128,activation = 'relu'))
model.add(tf.keras.layers.Dense(64,activation = 'relu'))
model.add(tf.keras.layers.Dense(1,activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               896
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 75,137
# Trainable params: 75,137
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model

# %%
model.compile(loss = 'binary_crossentropy',optimizer = 'rmsprop',metrics = ['acc'])

# %% [markdown]
# ### Training the model

# %%
history= model.fit(x_train,y_train,epochs = 50,batch_size = 128,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 75/75 [==============================] - 4s 9ms/step - loss: 1.4022 - acc: 0.5442 - val_loss: 0.8192 - val_acc: 0.4427
# Epoch 2/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.4668 - acc: 0.7511 - val_loss: 0.3253 - val_acc: 0.9650
# Epoch 3/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.3349 - acc: 0.8991 - val_loss: 0.6400 - val_acc: 0.5927
# Epoch 4/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2409 - acc: 0.9351 - val_loss: 0.1794 - val_acc: 0.9492
# Epoch 5/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1946 - acc: 0.9415 - val_loss: 0.1082 - val_acc: 0.9692
# Epoch 6/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1550 - acc: 0.9494 - val_loss: 0.1164 - val_acc: 0.9788
# Epoch 7/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1003 - acc: 0.9705 - val_loss: 0.0870 - val_acc: 0.9733
# Epoch 8/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0909 - acc: 0.9753 - val_loss: 0.0922 - val_acc: 0.9821
# Epoch 9/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0971 - acc: 0.9726 - val_loss: 0.1084 - val_acc: 0.9700
# Epoch 10/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0753 - acc: 0.9801 - val_loss: 0.0744 - val_acc: 0.9771
# Epoch 11/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0800 - acc: 0.9775 - val_loss: 0.2509 - val_acc: 0.8605
# Epoch 12/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0693 - acc: 0.9819 - val_loss: 0.0590 - val_acc: 0.9833
# Epoch 13/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0665 - acc: 0.9810 - val_loss: 0.0804 - val_acc: 0.9725
# Epoch 14/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0630 - acc: 0.9830 - val_loss: 0.0570 - val_acc: 0.9850
# Epoch 15/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0619 - acc: 0.9842 - val_loss: 0.0650 - val_acc: 0.9792
# Epoch 16/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0639 - acc: 0.9840 - val_loss: 0.0544 - val_acc: 0.9838
# Epoch 17/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0606 - acc: 0.9832 - val_loss: 0.0515 - val_acc: 0.9846
# Epoch 18/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0564 - acc: 0.9859 - val_loss: 0.1136 - val_acc: 0.9575
# Epoch 19/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0594 - acc: 0.9832 - val_loss: 0.0514 - val_acc: 0.9854
# Epoch 20/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0551 - acc: 0.9860 - val_loss: 0.0465 - val_acc: 0.9871
# Epoch 21/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0561 - acc: 0.9845 - val_loss: 0.0468 - val_acc: 0.9846
# Epoch 22/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0539 - acc: 0.9847 - val_loss: 0.0464 - val_acc: 0.9858
# Epoch 23/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0532 - acc: 0.9858 - val_loss: 0.0900 - val_acc: 0.9854
# Epoch 24/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0540 - acc: 0.9866 - val_loss: 0.0699 - val_acc: 0.9838
# Epoch 25/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0512 - acc: 0.9860 - val_loss: 0.0485 - val_acc: 0.9883
# Epoch 26/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0516 - acc: 0.9854 - val_loss: 0.0440 - val_acc: 0.9867
# Epoch 27/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0479 - acc: 0.9866 - val_loss: 0.0420 - val_acc: 0.9867
# Epoch 28/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0482 - acc: 0.9861 - val_loss: 0.0373 - val_acc: 0.9875
# Epoch 29/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0565 - acc: 0.9868 - val_loss: 0.0358 - val_acc: 0.9892
# Epoch 30/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0406 - acc: 0.9889 - val_loss: 0.0392 - val_acc: 0.9892
# Epoch 31/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0441 - acc: 0.9883 - val_loss: 0.0387 - val_acc: 0.9892
# Epoch 32/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0455 - acc: 0.9878 - val_loss: 0.0369 - val_acc: 0.9904
# Epoch 33/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0447 - acc: 0.9882 - val_loss: 0.0911 - val_acc: 0.9625
# Epoch 34/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0882 - acc: 0.9861 - val_loss: 0.0382 - val_acc: 0.9892
# Epoch 35/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0409 - acc: 0.9885 - val_loss: 0.0373 - val_acc: 0.9879
# Epoch 36/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0420 - acc: 0.9884 - val_loss: 0.2421 - val_acc: 0.8784
# Epoch 37/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0485 - acc: 0.9881 - val_loss: 0.0351 - val_acc: 0.9892
# Epoch 38/50
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1815 - acc: 0.9884 - val_loss: 0.1103 - val_acc: 0.9554
# Epoch 39/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0403 - acc: 0.9882 - val_loss: 0.0391 - val_acc: 0.9908
# Epoch 40/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0458 - acc: 0.9897 - val_loss: 0.0336 - val_acc: 0.9896
# Epoch 41/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0417 - acc: 0.9874 - val_loss: 0.0372 - val_acc: 0.9892
# Epoch 42/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0385 - acc: 0.9889 - val_loss: 0.0582 - val_acc: 0.9879
# Epoch 43/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0486 - acc: 0.9866 - val_loss: 0.0359 - val_acc: 0.9908
# Epoch 44/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0355 - acc: 0.9894 - val_loss: 0.0372 - val_acc: 0.9858
# Epoch 45/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0429 - acc: 0.9871 - val_loss: 0.0298 - val_acc: 0.9900
# Epoch 46/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0381 - acc: 0.9887 - val_loss: 0.0358 - val_acc: 0.9879
# Epoch 47/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0357 - acc: 0.9890 - val_loss: 0.0349 - val_acc: 0.9883
# Epoch 48/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0477 - acc: 0.9880 - val_loss: 0.0285 - val_acc: 0.9900
# Epoch 49/50
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0383 - acc: 0.9889 - val_loss: 0.0292 - val_acc: 0.9908
# Epoch 50/50
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0380 - acc: 0.9883 - val_loss: 0.0254 - val_acc: 0.9908

# %% [markdown]
# ### Plotting the results

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc="lower right")
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc="lower right")
plt.show()

# %%
model.evaluate(x_test,y_test)
# Out:
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0254 - acc: 0.9908
# [0.02535383030772209, 0.9908371567726135]

# %% [markdown]
# ### Model Predictions

# %%
x_test.reset_index(drop = True, inplace =True)

# %%
y_test.reset_index(drop = True, inplace = True)

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2401 entries, 0 to 2400
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ia      2401 non-null   float64
#  1   Ia      2401 non-null   float64
#  2   Ic      2401 non-null   float64
#  3   Va      2401 non-null   float64
#  4   Vb      2401 non-null   float64
#  5   Vc      2401 non-null   float64
# dtypes: float64(6)
# memory usage: 112.7 KB

# %%
y_test.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Output (S), dtype: int64

# %%
y_t = model.predict(x_test)
# Out:
# 76/76 [==============================] - 0s 1ms/step

# %% [markdown]
# ### Checking the predictions

# %%
i = int(input("Enter any number between 1 to 2400 : "))
# Out:
# Enter any number between 1 to 2400 : 252

# %%
print(f"The prediction of the {i}th value of the x_test is :",np.max(y_t[i][0]))
print(f"The actual value of the ith value of the x_test is :",y_test[i])
# Out:
# The prediction of the 252th value of the x_test is : 6.203547e-05
# The actual value of the ith value of the x_test is : 0
